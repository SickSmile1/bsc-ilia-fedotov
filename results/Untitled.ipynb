# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("pressure_mass_flow_releation.csv", delimiter=",", skiprows=1)
#data = data.T
plt.plot(data[1], data[0])
plt.show()

# %%
data[0]
# Out:
# array([600.        ,   4.99872649])
