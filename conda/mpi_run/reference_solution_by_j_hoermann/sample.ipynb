# %%
# ---
# jupyter:
#   jupytext:
#     text_representation:
#       extension: .py
#       format_name: percent
#       format_version: '1.3'
#       jupytext_version: 1.16.2
#   kernelspec:
#     display_name: Python 3 (ipykernel)
#     language: python
#     name: python3
# ---

# %%
from mpi4py import MPI
from petsc4py import PETSc
import numpy as np
import pyvista

from dolfinx.fem import Constant, Function, functionspace, assemble_scalar, dirichletbc, form, locate_dofs_geometrical, locate_dofs_topological
from dolfinx.fem.petsc import assemble_matrix, assemble_vector, apply_lifting, create_vector, set_bc
from dolfinx.io import VTXWriter
from dolfinx.mesh import create_unit_square
from dolfinx.plot import vtk_mesh
from basix.ufl import element
from ufl import (FacetNormal, Identity, TestFunction, TrialFunction, Measure,
                 div, dot, ds, dx, inner, lhs, nabla_grad, rhs, sym)
import dolfinx

# %%
import gmsh
from dolfinx.io import gmshio

# %%
import matplotlib.pyplot as plt

# %%
import logging
# %%
logging.basicConfig(level=logging.INFO)

logging.getLogger("trame_server").setLevel(logging.WARNING)
logging.getLogger("trame_client").setLevel(logging.WARNING)
# %%
logger = logging.getLogger()


# %%
def create_mesh(comm, H=1, L=6, lc=.01, filename="mesh.msh"):
    """
    Create a 2D mesh of a canal using GMSH.

    This function generates a mesh for a rectangular canal. It uses GMSH for mesh generation and MPI for parallel processing.

    :param comm: MPI communicator
        The MPI communicator object for parallel processing.
    :param H: float, optional
        Height of the canal (default is 1).
    :param L: float, optional
        Length of the canal (default is 3).
    :param lc: float, optional
        Characteristic length for mesh generation (default is 0.07).

    :return: tuple
        A tuple containing:
        - mesh: dolfinx.mesh.Mesh
            The generated mesh.
        - ct: dolfinx.mesh.MeshTags
            Cell tags for the mesh.
        - ft: dolfinx.mesh.MeshTags
            Facet tags for the mesh.
        - infl: int
            Tag for the inflow boundary.
        - outfl: int
            Tag for the outflow boundary.
        - upper: int
            Tag for the upper wall boundary.
        - lower: int
            Tag for the lower wall boundary.

    :raises: None explicitly, but may raise exceptions from GMSH or MPI operations.

    .. note::
        - This function uses GMSH for mesh generation and dolfinx for mesh representation.
        - The mesh is generated only on the process with rank 0 and then broadcast to all processes.
        - The function defines physical groups for different parts of the geometry (inflow, outflow, walls).

    .. warning::
        Ensure that GMSH and dolfinx are properly installed and imported in your environment.

    Example:
        >>> from mpi4py import MPI
        >>> comm = MPI.COMM_WORLD
        >>> mesh, ct, ft, infl, outfl, upper, lower = create_obst(comm)
    """
    Ox = L/2
    r = .3
    model_rank = 0
    infl, outfl, upper, lower = [],[],[],[]
    if comm.rank == model_rank:
        gmsh.initialize()
        gmsh.model.add("canal")
        
        cm = 1 # e-02 # not needed for our sim
        h1 = H * cm
        l1 = L * cm
        Lc1 = lc
        
        # We start by defining some points and some lines. To make the code shorter we
        # can redefine a namespace:
        factory = gmsh.model.geo
        model = gmsh.model
        
        p_lower_left = factory.addPoint(0, 0, 0, Lc1)
        p_lower_right = factory.addPoint(l1, 0, 0, Lc1)
        p_upper_right = factory.addPoint(l1, h1 , 0, Lc1)
        p_upper_left = factory.addPoint(0, h1, 0, Lc1)
        
        l_lower = factory.addLine(p_lower_left, p_lower_right)
        l_right = factory.addLine(p_lower_right, p_upper_right)
        # l_upper = factory.addLine(p_upper_right, p_upper_left)
        l_left = factory.addLine(p_upper_left, p_lower_left)

        p_left_c = factory.addPoint(Ox-r, h1, 0, Lc1)
        p_mid_c = factory.addPoint(Ox, h1, 0, Lc1)
        p_right_c = factory.addPoint(Ox+r, h1, 0, Lc1)
        
        l_upper_r = factory.addLine(p_upper_right, p_right_c)
        l_upper_l = factory.addLine(p_left_c, p_upper_left)
        
        arc1 = factory.addCircleArc(p_left_c, p_mid_c, p_right_c)
        
        courve1 = factory.addCurveLoop([-arc1])
        
        lines = [l_lower,l_right, l_upper_l, -arc1, l_upper_r, l_left]
        
        # Define the inner curve loop (the circle arc)
        loop = factory.addCurveLoop(lines)
    
        # Create the plane surface with a hole
        surface = factory.addPlaneSurface([loop])
        factory.synchronize()
        
        upper = model.addPhysicalGroup(1, [l_upper_l, -arc1, l_upper_r], tag=1, name="upper_wall")
        outfl = model.addPhysicalGroup(1, [l_right], tag=2, name="outfl")
        infl = model.addPhysicalGroup(1, [l_left], tag=3, name="inflow")
        lower = model.addPhysicalGroup(1, [l_lower], tag=4, name="lower_wall")

        gmsh.model.addPhysicalGroup(2, [surface], tag=5, name="Domain")
        
        factory.synchronize()
        gmsh.model.mesh.generate(2)
        gmsh.write(filename)
        
    # infl = comm.bcast(infl, root=0)
    # outfl = comm.bcast(outfl, root=0)
    # upper = comm.bcast(upper, root=0)
    # lower = comm.bcast(lower, root=0)
    # gmsh.model = comm.bcast(gmsh.model, root=0)
    mesh, ct, ft = gmshio.model_to_mesh(gmsh.model, comm, model_rank,gdim=2)
    return mesh, ct, ft, infl, outfl, upper, lower


# %%
mesh, ct, ft, inlet_marker,outlet_marker, upper_wall_marker, lower_wall_marker = create_mesh(MPI.COMM_WORLD, H=1, L=3, lc=0.05)

# %%
upper_wall_marker

# %%
T = .8
# num_steps = 50
dt = 0.0001 # T / num_steps
num_steps = int(T/dt)
relative_tolerance = 1.e-5

# %%
final_mass_flow_list = []
pressure_list = []
# Out:
# [sick:37857] shmem: mmap: an error occurred while determining whether or not /tmp/ompi.sick.1000/jf.0/3083075584/shared_mem_cuda_pool.sick could be created.
# [sick:37857] create_and_attach: unable to create shared memory BTL coordinating structure :: size 134217728
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 40%] Meshing curve 3 (Line)
# Info    : [ 60%] Meshing curve 4 (Line)
# Info    : [ 70%] Meshing curve 5 (Line)
# Info    : [ 90%] Meshing curve 6 (Circle)
# Info    : Done meshing 1D (Wall 0.000462735s, CPU 0.008379s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0572719s, CPU 0.20404s)
# Info    : 1450 nodes 2903 elements
# Info    : Writing 'mesh.msh'...
# Info    : Done writing 'mesh.msh'

# %%
for j, pressure in enumerate(np.arange(1000, 5000, 250)):
    # mesh = create_unit_square(MPI.COMM_WORLD, 10, 10)
    pressure_list.append(pressure)
    t = 0
    
    logger.info("RUN %d: pressure %d", j, pressure)

    v_cg2 = element("Lagrange", mesh.topology.cell_name(), 2, shape=(mesh.geometry.dim, ))
    s_cg1 = element("Lagrange", mesh.topology.cell_name(), 1)
    V = functionspace(mesh, v_cg2)
    Q = functionspace(mesh, s_cg1)
    
    u = TrialFunction(V)
    v = TestFunction(V)
    p = TrialFunction(Q)
    q = TestFunction(Q)
    
    # def walls(x):
    #    return np.logical_or(np.isclose(x[1], 0), np.isclose(x[1], 1))
    
    # wall_dofs = locate_dofs_geometrical(V, walls)
    # u_noslip = np.array((0,) * mesh.geometry.dim, dtype=PETSc.ScalarType)
    # bc_noslip = dirichletbc(u_noslip, wall_dofs, V)
    
    # def inflow(x):
    #    return np.isclose(x[0], 0)
    
    # inflow_dofs = locate_dofs_geometrical(Q, inflow)
    # bc_inflow = dirichletbc(PETSc.ScalarType(pressure), inflow_dofs, Q)
    
    # def outflow(x):
    #    return np.isclose(x[0], 1)
    
    # outflow_dofs = locate_dofs_geometrical(Q, outflow)
    # bc_outflow = dirichletbc(PETSc.ScalarType(0), outflow_dofs, Q)
    # bcu = [bc_noslip]
    # bcp = [bc_inflow, bc_outflow]

    fdim = mesh.topology.dim - 1

    upper_wall_dofs = locate_dofs_topological(V, fdim, ft.find(upper_wall_marker))
    u_noslip = np.array((0,) * mesh.geometry.dim, dtype=PETSc.ScalarType)
    bc_noslip1 = dirichletbc(u_noslip, upper_wall_dofs, V)

    lower_wall_dofs = locate_dofs_topological(V, fdim, ft.find(lower_wall_marker))
    u_noslip = np.array((0,) * mesh.geometry.dim, dtype=PETSc.ScalarType)
    bc_noslip2 = dirichletbc(u_noslip, lower_wall_dofs, V)
    
    inflow_dofs = locate_dofs_topological(Q, fdim, ft.find(inlet_marker))
    bc_inflow = dirichletbc(PETSc.ScalarType(pressure), inflow_dofs, Q)
    
    outflow_dofs = locate_dofs_topological(Q, fdim, ft.find(outlet_marker))
    bc_outflow = dirichletbc(PETSc.ScalarType(0), outflow_dofs, Q)
    bcu = [bc_noslip1, bc_noslip2]
    bcp = [bc_inflow, bc_outflow]
    
    u_n = Function(V)
    u_n.name = "u_n"
    U = 0.5 * (u_n + u)
    n = FacetNormal(mesh)
    f = Constant(mesh, PETSc.ScalarType((0, 0)))
    k = Constant(mesh, PETSc.ScalarType(dt))
    mu = Constant(mesh, PETSc.ScalarType(1))
    rho = Constant(mesh, PETSc.ScalarType(1))
    
    # Define strain-rate tensor
    def epsilon(u):
        return sym(nabla_grad(u))
    
    # Define stress tensor
    def sigma(u, p):
        return 2 * mu * epsilon(u) - p * Identity(len(u))
    
    # Define the variational problem for the first step
    p_n = Function(Q)
    p_n.name = "p_n"
    F1 = rho * dot((u - u_n) / k, v) * dx
    F1 += rho * dot(dot(u_n, nabla_grad(u_n)), v) * dx
    F1 += inner(sigma(U, p_n), epsilon(v)) * dx
    F1 += dot(p_n * n, v) * ds - dot(mu * nabla_grad(U) * n, v) * ds
    F1 -= dot(f, v) * dx
    a1 = form(lhs(F1))
    L1 = form(rhs(F1))
    
    A1 = assemble_matrix(a1, bcs=bcu)
    A1.assemble()
    b1 = create_vector(L1)
    
    # Define variational problem for step 2
    u_ = Function(V)
    a2 = form(dot(nabla_grad(p), nabla_grad(q)) * dx)
    L2 = form(dot(nabla_grad(p_n), nabla_grad(q)) * dx - (rho / k) * div(u_) * q * dx)
    A2 = assemble_matrix(a2, bcs=bcp)
    A2.assemble()
    b2 = create_vector(L2)
    
    # Define variational problem for step 3
    p_ = Function(Q)
    a3 = form(rho * dot(u, v) * dx)
    L3 = form(rho * dot(u_, v) * dx - k * dot(nabla_grad(p_ - p_n), v) * dx)
    A3 = assemble_matrix(a3)
    A3.assemble()
    b3 = create_vector(L3)
    
    # Solver for step 1
    solver1 = PETSc.KSP().create(mesh.comm)
    solver1.setOperators(A1)
    solver1.setType(PETSc.KSP.Type.BCGS)
    pc1 = solver1.getPC()
    pc1.setType(PETSc.PC.Type.HYPRE)
    pc1.setHYPREType("boomeramg")
    
    # Solver for step 2
    solver2 = PETSc.KSP().create(mesh.comm)
    solver2.setOperators(A2)
    solver2.setType(PETSc.KSP.Type.BCGS)
    pc2 = solver2.getPC()
    pc2.setType(PETSc.PC.Type.HYPRE)
    pc2.setHYPREType("boomeramg")
    
    # Solver for step 3
    solver3 = PETSc.KSP().create(mesh.comm)
    solver3.setOperators(A3)
    solver3.setType(PETSc.KSP.Type.CG)
    pc3 = solver3.getPC()
    pc3.setType(PETSc.PC.Type.SOR)
    
    from pathlib import Path
    folder = Path(f"results/{pressure}")
    folder.mkdir(exist_ok=True, parents=True)
    """vtx_u = VTXWriter(mesh.comm, folder / "poiseuille_u.bp", u_n, engine="BP4")
    vtx_p = VTXWriter(mesh.comm, folder / "poiseuille_p.bp", p_n, engine="BP4")
    vtx_u.write(t)
    vtx_p.write(t)"""
    
    def u_exact(x):
        values = np.zeros((2, x.shape[1]), dtype=PETSc.ScalarType)
        values[0] = 4 * x[1] * (1.0 - x[1])
        return values
    
    
    u_ex = Function(V)
    u_ex.interpolate(u_exact)
    
    L2_error = form(dot(u_ - u_ex, u_ - u_ex) * dx)
    
    left_boundary = ft.find(inlet_marker)
    right_boundary = ft.find(outlet_marker)
    upper_boundary = ft.find(upper_wall_marker)
    lower_boundary = ft.find(lower_wall_marker)
    
    logger.info("facets with tag 3: %s", left_boundary)
    logger.info("number of facets with tag 3: %s", len(left_boundary))
    
    logger.info("facets with tag 2: %s", right_boundary)
    logger.info("number of facets with tag 2: %s", len(right_boundary))
    
    logger.info("facets with tag 1: %s", upper_boundary)
    logger.info("number of facets with tag 1: %s", len(upper_boundary))
    
    logger.info("facets with tag 4: %s", lower_boundary)
    logger.info("number of facets with tag 4: %s", len(lower_boundary))
    
    # create new MeshTags object to mark rough boundary
    left_boundary_facet_tags = dolfinx.mesh.meshtags(mesh, mesh.topology.dim-1, left_boundary, np.full_like(left_boundary, 1, dtype=np.int32))
    right_boundary_facet_tags = dolfinx.mesh.meshtags(mesh, mesh.topology.dim-1, right_boundary, np.full_like(right_boundary, 1, dtype=np.int32))
    upper_boundary_facet_tags = dolfinx.mesh.meshtags(mesh, mesh.topology.dim-1, upper_boundary, np.full_like(upper_boundary, 1, dtype=np.int32))
    lower_boundary_facet_tags = dolfinx.mesh.meshtags(mesh, mesh.topology.dim-1, lower_boundary, np.full_like(lower_boundary, 1, dtype=np.int32))
    
    left_boundary_ds = Measure("ds", domain=mesh, subdomain_data=left_boundary_facet_tags)
    right_boundary_ds = Measure("ds", domain=mesh, subdomain_data=right_boundary_facet_tags)
    upper_boundary_ds = Measure("ds", domain=mesh, subdomain_data=upper_boundary_facet_tags)
    lower_boundary_ds = Measure("ds", domain=mesh, subdomain_data=lower_boundary_facet_tags)
    
    # x = SpatialCoordinate(mesh)
    # n = FacetNormal(mesh)
    mfl = dot(u_n, n)
    # mfl = u_n[0]
    
    mfl_left_expression = form(mfl*left_boundary_ds)
    mfl_right_expression = form(mfl*right_boundary_ds)
    mfl_upper_expression = form(mfl*upper_boundary_ds)
    mfl_lower_expression = form(mfl*lower_boundary_ds)
    
    mass_flow_left_list = []
    mass_flow_right_list = []
    
    bb_tree = dolfinx.geometry.bb_tree(mesh, mesh.topology.dim)
    
    N_points = 100
    
    y_grid = np.linspace(0, 1, N_points)
    
    points = np.zeros((3, N_points))
    points[0, :] = 0.5
    points[1, :] = y_grid
    
    # Find cells whose bounding-box collide with the points
    cell_candidates = dolfinx.geometry.compute_collisions_points(bb_tree, points.T)
    # Choose one of the cells that contains the point
    colliding_cells = dolfinx.geometry.compute_colliding_cells(mesh, cell_candidates, points.T)
    
    # numerical integaration along cross-section
    points_on_proc = []
    cells = []
    
    for i, point in enumerate(points.T):
        if len(colliding_cells.links(i)) > 0:
            points_on_proc.append(point)
            cells.append(colliding_cells.links(i)[0])
        else:
            logger.warning("Point %d: %s not in domain", i, point)
    
    points_on_proc = np.array(points_on_proc, dtype=np.float64)
    
    velocity_profiles = []
    
    mass_flow_through_cross_section_list = []

    time_list = []
    
    for i in range(num_steps):
        # Update current time step
        t += dt

        time_list.append(t)
        
        # Step 1: Tentative veolcity step
        with b1.localForm() as loc_1:
            loc_1.set(0)
        assemble_vector(b1, L1)
        apply_lifting(b1, [a1], [bcu])
        b1.ghostUpdate(addv=PETSc.InsertMode.ADD_VALUES, mode=PETSc.ScatterMode.REVERSE)
        set_bc(b1, bcu)
        solver1.solve(b1, u_.x.petsc_vec)
        u_.x.scatter_forward()
    
        # Step 2: Pressure corrrection step
        with b2.localForm() as loc_2:
            loc_2.set(0)
        assemble_vector(b2, L2)
        apply_lifting(b2, [a2], [bcp])
        b2.ghostUpdate(addv=PETSc.InsertMode.ADD_VALUES, mode=PETSc.ScatterMode.REVERSE)
        set_bc(b2, bcp)
        solver2.solve(b2, p_.x.petsc_vec)
        p_.x.scatter_forward()
    
        # Step 3: Velocity correction step
        with b3.localForm() as loc_3:
            loc_3.set(0)
        assemble_vector(b3, L3)
        b3.ghostUpdate(addv=PETSc.InsertMode.ADD_VALUES, mode=PETSc.ScatterMode.REVERSE)
        solver3.solve(b3, u_.x.petsc_vec)
        u_.x.scatter_forward()
        # Update variable with solution form this time step
        u_n.x.array[:] = u_.x.array[:]
        p_n.x.array[:] = p_.x.array[:]
    
        # Define measures and spatial coordinates
        mfl_left_local = assemble_scalar(form(mfl_left_expression))
        mass_flow_left = mesh.comm.allreduce(mfl_left_local, op=MPI.SUM)
    
        mfl_right_local = assemble_scalar(form(mfl_right_expression))
        mass_flow_right = mesh.comm.allreduce(mfl_right_local, op=MPI.SUM)
    
        mfl_upper_local = assemble_scalar(form(mfl_upper_expression))
        mass_flow_upper = mesh.comm.allreduce(mfl_upper_local, op=MPI.SUM)
    
        mfl_lower_local = assemble_scalar(form(mfl_lower_expression))
        mass_flow_lower = mesh.comm.allreduce(mfl_lower_local, op=MPI.SUM)
    
        velocity_profile = u_n.eval(points_on_proc, cells).T
    
        mass_flow_through_cross_section = np.trapz(y=velocity_profile[0], x=y_grid)
        
        velocity_profiles.append(velocity_profile)
        mass_flow_through_cross_section_list.append(mass_flow_through_cross_section)
        
        mass_flow_left_list.append(mass_flow_left)
        mass_flow_right_list.append(mass_flow_right)

        #vtx_u.write(t)
        #vtx_p.write(t)
        # Compute error at current time-step
        # error_L2 = np.sqrt(mesh.comm.allreduce(assemble_scalar(L2_error), op=MPI.SUM))
        # error_max = mesh.comm.allreduce(np.max(u_.x.petsc_vec.array - u_ex.x.petsc_vec.array), op=MPI.MAX)
        # Print error only every 20th step and at the last step
        if (i % 20 == 0) or (i == num_steps - 1):
            logger.info(
                f"Time {t:.2f}, Flux left {mass_flow_left:.2e}, Flux right {mass_flow_right:.2e}, Flux upper {mass_flow_upper:.2e}, Flux lower {mass_flow_lower:.2e}, Flux center {mass_flow_through_cross_section:.2e}")        

        if len(mass_flow_through_cross_section_list) > 1:
            mean_of_last_two = np.mean(mass_flow_through_cross_section_list[-2:])
            dm = np.abs(mass_flow_through_cross_section_list[-1] - mass_flow_through_cross_section_list[-2])
            relative_deviation = dm / mean_of_last_two
            logger.debug("Absolute deviation: %g", dm)
            logger.debug("Relative deviation: %g", relative_deviation)
            if relative_deviation < 2*relative_tolerance:
                logger.info("Relative mass flow change %g converged within relatvie tolerance %g", relative_deviation, relative_tolerance)
                break
            
    # Close xmdf file
    #vtx_u.close()
    #vtx_p.close()
    b1.destroy()
    b2.destroy()
    b3.destroy()
    solver1.destroy()
    solver2.destroy()
    solver3.destroy()

    # np.array(velocity_profile)
    cross_section_data = np.vstack([points[1,:], velocity_profile[0]])
    np.savetxt(folder / "cross_section_velocity_profile.csv", cross_section_data.T, delimiter=",", header="position, velocity")

    mass_flow_evolution = np.vstack([np.array(time_list), np.array(mass_flow_through_cross_section_list)])
    np.savetxt(folder / "mass_flow_evolution.csv", mass_flow_evolution.T, delimiter=",", header="time, flux")

    final_mass_flow_list.append(mass_flow_through_cross_section)
    pyvista.start_xvfb()
    topology, cell_types, geometry = vtk_mesh(V)
    values = np.zeros((geometry.shape[0], 3), dtype=np.float64)
    values[:, :len(u_n)] = u_n.x.array.real.reshape((geometry.shape[0], len(u_n)))
    
    # Create a point cloud of glyphs
    function_grid = pyvista.UnstructuredGrid(topology, cell_types, geometry)
    function_grid["u"] = values
    glyphs = function_grid.glyph(orient="u", scale=False, factor=0.2) #orient="u", factor=0.2)
    
    # Create a pyvista-grid for the mesh
    mesh.topology.create_connectivity(mesh.topology.dim, mesh.topology.dim)
    grid = pyvista.UnstructuredGrid(*vtk_mesh(mesh, mesh.topology.dim))
    
    # Create plotter
    plotter = pyvista.Plotter()
    plotter.add_mesh(grid, style="wireframe", color="k")
    plotter.add_mesh(glyphs)
    plotter.view_xy()
    if not pyvista.OFF_SCREEN:
        plotter.show()
        fig_as_array = plotter.screenshot(f"pics/glyphs_{pressure}.png")
    else:
        fig_as_array = plotter.screenshot("glyphs.png")

pressure_mass_flow_releation = np.vstack([np.array(pressure_list), np.array(final_mass_flow_list)])
np.savetxt("results/pressure_mass_flow_releation.csv", pressure_mass_flow_releation.T, delimiter=",", header="pressure, flux")

# %%
plt.plot(pressure_mass_flow_releation[0], pressure_mass_flow_releation[1])

# %%
"""pyvista.start_xvfb()
topology, cell_types, geometry = vtk_mesh(V)
values = np.zeros((geometry.shape[0], 3), dtype=np.float64)
values[:, :len(u_n)] = u_n.x.array.real.reshape((geometry.shape[0], len(u_n)))

# Create a point cloud of glyphs
function_grid = pyvista.UnstructuredGrid(topology, cell_types, geometry)
function_grid["u"] = values
glyphs = function_grid.glyph(orient="u", factor=0.2)

# Create a pyvista-grid for the mesh
mesh.topology.create_connectivity(mesh.topology.dim, mesh.topology.dim)
grid = pyvista.UnstructuredGrid(*vtk_mesh(mesh, mesh.topology.dim))

# Create plotter
plotter = pyvista.Plotter()
plotter.add_mesh(grid, style="wireframe", color="k")
plotter.add_mesh(glyphs)
plotter.view_xy()
if not pyvista.OFF_SCREEN:
    plotter.show()
else:
    fig_as_array = plotter.screenshot("glyphs.png")"""

# %%
# Out:
# INFO:root:RUN 0: pressure 1000
# INFO:root:facets with tag 3: [  0   2   6  13  26  32  45  58  62  77  94 113 124 146 149 156 185 186
#  191 205]
# INFO:root:number of facets with tag 3: 20
# INFO:root:facets with tag 2: [3916 3948 3949 3980 4034 4054 4083 4099 4100 4118 4139 4140 4152 4168
#  4169 4170 4171 4172 4175 4176]
# INFO:root:number of facets with tag 2: 20
# INFO:root:facets with tag 1: [ 188  196  274  345  417  488  558  627  694  762  832  900  968 1038
#  1107 1171 1238 1306 1379 1445 1513 1582 1650 1713 1726 1780 1840 1893
#  1949 2000 2051 2076 2122 2189 2238 2287 2336 2387 2439 2495 2555 2618
#  2686 2699 2760 2827 2857 2922 2989 3056 3124 3193 3260 3327 3395 3465
#  3535 3605 3676 3746 3818 3889 3951 4013 4064 4108 4142]
# INFO:root:number of facets with tag 1: 67
# INFO:root:facets with tag 4: [ 285  340  359  412  444  484  518  582  654  724  795  867  898  942
#  1013 1084 1151 1218 1286 1358 1425 1494 1559 1629 1693 1764 1827 1887
#  1944 1995 2047 2096 2142 2187 2234 2285 2334 2385 2437 2490 2550 2613
#  2684 2756 2826 2897 2964 3033 3101 3169 3241 3309 3380 3444 3511 3578
#  3644 3710 3780 3850]
# INFO:root:number of facets with tag 4: 60
# WARNING:py.warnings:/tmp/ipykernel_37857/1626486534.py:274: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   mass_flow_through_cross_section = np.trapz(y=velocity_profile[0], x=y_grid)
#
# INFO:root:Time 0.00, Flux left 1.27e-04, Flux right 1.27e-04, Flux upper 1.27e-04, Flux lower 1.27e-04, Flux center 3.03e-02
# INFO:root:Time 0.00, Flux left 7.60e-06, Flux right 7.60e-06, Flux upper 7.60e-06, Flux lower 7.60e-06, Flux center 5.85e-01
# INFO:root:Time 0.00, Flux left 8.76e-06, Flux right 8.76e-06, Flux upper 8.76e-06, Flux lower 8.76e-06, Flux center 1.10e+00
# INFO:root:Time 0.01, Flux left 9.37e-06, Flux right 9.37e-06, Flux upper 9.37e-06, Flux lower 9.37e-06, Flux center 1.60e+00
# INFO:root:Time 0.01, Flux left 9.10e-06, Flux right 9.10e-06, Flux upper 9.10e-06, Flux lower 9.10e-06, Flux center 2.07e+00
# INFO:root:Time 0.01, Flux left 8.25e-06, Flux right 8.25e-06, Flux upper 8.25e-06, Flux lower 8.25e-06, Flux center 2.52e+00
# INFO:root:Time 0.01, Flux left 7.03e-06, Flux right 7.03e-06, Flux upper 7.03e-06, Flux lower 7.03e-06, Flux center 2.96e+00
# INFO:root:Time 0.01, Flux left 5.55e-06, Flux right 5.55e-06, Flux upper 5.55e-06, Flux lower 5.55e-06, Flux center 3.39e+00
# INFO:root:Time 0.02, Flux left 3.91e-06, Flux right 3.91e-06, Flux upper 3.91e-06, Flux lower 3.91e-06, Flux center 3.80e+00
# INFO:root:Time 0.02, Flux left 2.15e-06, Flux right 2.15e-06, Flux upper 2.15e-06, Flux lower 2.15e-06, Flux center 4.20e+00
# INFO:root:Time 0.02, Flux left 3.09e-07, Flux right 3.09e-07, Flux upper 3.09e-07, Flux lower 3.09e-07, Flux center 4.58e+00
# INFO:root:Time 0.02, Flux left -1.59e-06, Flux right -1.59e-06, Flux upper -1.59e-06, Flux lower -1.59e-06, Flux center 4.96e+00
# INFO:root:Time 0.02, Flux left -3.52e-06, Flux right -3.52e-06, Flux upper -3.52e-06, Flux lower -3.52e-06, Flux center 5.33e+00
# INFO:root:Time 0.03, Flux left -5.48e-06, Flux right -5.48e-06, Flux upper -5.48e-06, Flux lower -5.48e-06, Flux center 5.68e+00
# INFO:root:Time 0.03, Flux left -7.46e-06, Flux right -7.46e-06, Flux upper -7.46e-06, Flux lower -7.46e-06, Flux center 6.03e+00
# INFO:root:Time 0.03, Flux left -9.45e-06, Flux right -9.45e-06, Flux upper -9.45e-06, Flux lower -9.45e-06, Flux center 6.36e+00
# INFO:root:Time 0.03, Flux left -1.14e-05, Flux right -1.14e-05, Flux upper -1.14e-05, Flux lower -1.14e-05, Flux center 6.69e+00
# INFO:root:Time 0.07, Flux left -6.63e-05, Flux right -6.63e-05, Flux upper -6.63e-05, Flux lower -6.63e-05, Flux center 1.18e+01
# INFO:root:Time 0.08, Flux left -7.06e-05, Flux right -7.06e-05, Flux upper -7.06e-05, Flux lower -7.06e-05, Flux center 1.20e+01
# INFO:root:Time 0.08, Flux left -7.50e-05, Flux right -7.50e-05, Flux upper -7.50e-05, Flux lower -7.50e-05, Flux center 1.22e+01
# INFO:root:Time 0.08, Flux left -7.96e-05, Flux right -7.96e-05, Flux upper -7.96e-05, Flux lower -7.96e-05, Flux center 1.24e+01
# INFO:root:Time 0.08, Flux left -8.43e-05, Flux right -8.43e-05, Flux upper -8.43e-05, Flux lower -8.43e-05, Flux center 1.25e+01
# INFO:root:Time 0.08, Flux left -8.92e-05, Flux right -8.92e-05, Flux upper -8.92e-05, Flux lower -8.92e-05, Flux center 1.27e+01
# INFO:root:Time 0.09, Flux left -9.42e-05, Flux right -9.42e-05, Flux upper -9.42e-05, Flux lower -9.42e-05, Flux center 1.29e+01
# INFO:root:Time 0.09, Flux left -9.93e-05, Flux right -9.93e-05, Flux upper -9.93e-05, Flux lower -9.93e-05, Flux center 1.30e+01
# INFO:root:Time 0.09, Flux left -1.05e-04, Flux right -1.05e-04, Flux upper -1.05e-04, Flux lower -1.05e-04, Flux center 1.32e+01
# INFO:root:Time 0.09, Flux left -1.10e-04, Flux right -1.10e-04, Flux upper -1.10e-04, Flux lower -1.10e-04, Flux center 1.33e+01
# INFO:root:Time 0.09, Flux left -1.15e-04, Flux right -1.15e-04, Flux upper -1.15e-04, Flux lower -1.15e-04, Flux center 1.34e+01
# INFO:root:Time 0.10, Flux left -1.21e-04, Flux right -1.21e-04, Flux upper -1.21e-04, Flux lower -1.21e-04, Flux center 1.36e+01
# INFO:root:Time 0.10, Flux left -1.26e-04, Flux right -1.26e-04, Flux upper -1.26e-04, Flux lower -1.26e-04, Flux center 1.37e+01
# INFO:root:Time 0.10, Flux left -1.31e-04, Flux right -1.31e-04, Flux upper -1.31e-04, Flux lower -1.31e-04, Flux center 1.38e+01
# INFO:root:Time 0.10, Flux left -1.37e-04, Flux right -1.37e-04, Flux upper -1.37e-04, Flux lower -1.37e-04, Flux center 1.40e+01
# INFO:root:Time 0.10, Flux left -1.42e-04, Flux right -1.42e-04, Flux upper -1.42e-04, Flux lower -1.42e-04, Flux center 1.41e+01
# INFO:root:Time 0.11, Flux left -1.48e-04, Flux right -1.48e-04, Flux upper -1.48e-04, Flux lower -1.48e-04, Flux center 1.42e+01
# INFO:root:Time 0.11, Flux left -1.53e-04, Flux right -1.53e-04, Flux upper -1.53e-04, Flux lower -1.53e-04, Flux center 1.43e+01
# INFO:root:Time 0.11, Flux left -1.59e-04, Flux right -1.59e-04, Flux upper -1.59e-04, Flux lower -1.59e-04, Flux center 1.44e+01
# INFO:root:Time 0.11, Flux left -1.64e-04, Flux right -1.64e-04, Flux upper -1.64e-04, Flux lower -1.64e-04, Flux center 1.45e+01
# INFO:root:Time 0.11, Flux left -1.69e-04, Flux right -1.69e-04, Flux upper -1.69e-04, Flux lower -1.69e-04, Flux center 1.46e+01
# INFO:root:Time 0.12, Flux left -1.74e-04, Flux right -1.74e-04, Flux upper -1.74e-04, Flux lower -1.74e-04, Flux center 1.47e+01
# INFO:root:Time 0.12, Flux left -1.79e-04, Flux right -1.79e-04, Flux upper -1.79e-04, Flux lower -1.79e-04, Flux center 1.48e+01
# INFO:root:Time 0.12, Flux left -1.85e-04, Flux right -1.85e-04, Flux upper -1.85e-04, Flux lower -1.85e-04, Flux center 1.49e+01
# INFO:root:Time 0.12, Flux left -1.90e-04, Flux right -1.90e-04, Flux upper -1.90e-04, Flux lower -1.90e-04, Flux center 1.50e+01
# INFO:root:Time 0.12, Flux left -1.95e-04, Flux right -1.95e-04, Flux upper -1.95e-04, Flux lower -1.95e-04, Flux center 1.51e+01
# INFO:root:Time 0.13, Flux left -2.00e-04, Flux right -2.00e-04, Flux upper -2.00e-04, Flux lower -2.00e-04, Flux center 1.52e+01
# INFO:root:Time 0.13, Flux left -2.04e-04, Flux right -2.04e-04, Flux upper -2.04e-04, Flux lower -2.04e-04, Flux center 1.53e+01
# INFO:root:Time 0.13, Flux left -2.09e-04, Flux right -2.09e-04, Flux upper -2.09e-04, Flux lower -2.09e-04, Flux center 1.54e+01
# INFO:root:Time 0.13, Flux left -2.14e-04, Flux right -2.14e-04, Flux upper -2.14e-04, Flux lower -2.14e-04, Flux center 1.55e+01
# INFO:root:Time 0.13, Flux left -2.19e-04, Flux right -2.19e-04, Flux upper -2.19e-04, Flux lower -2.19e-04, Flux center 1.56e+01
# INFO:root:Time 0.14, Flux left -2.23e-04, Flux right -2.23e-04, Flux upper -2.23e-04, Flux lower -2.23e-04, Flux center 1.56e+01
# INFO:root:Time 0.14, Flux left -2.28e-04, Flux right -2.28e-04, Flux upper -2.28e-04, Flux lower -2.28e-04, Flux center 1.57e+01
# INFO:root:Time 0.14, Flux left -2.32e-04, Flux right -2.32e-04, Flux upper -2.32e-04, Flux lower -2.32e-04, Flux center 1.58e+01
# INFO:root:Time 0.14, Flux left -2.37e-04, Flux right -2.37e-04, Flux upper -2.37e-04, Flux lower -2.37e-04, Flux center 1.59e+01
# INFO:root:Time 0.14, Flux left -2.41e-04, Flux right -2.41e-04, Flux upper -2.41e-04, Flux lower -2.41e-04, Flux center 1.59e+01
# INFO:root:Time 0.15, Flux left -2.45e-04, Flux right -2.45e-04, Flux upper -2.45e-04, Flux lower -2.45e-04, Flux center 1.60e+01
# INFO:root:Time 0.15, Flux left -2.49e-04, Flux right -2.49e-04, Flux upper -2.49e-04, Flux lower -2.49e-04, Flux center 1.61e+01
# INFO:root:Time 0.15, Flux left -2.53e-04, Flux right -2.53e-04, Flux upper -2.53e-04, Flux lower -2.53e-04, Flux center 1.61e+01
# INFO:root:Time 0.15, Flux left -2.57e-04, Flux right -2.57e-04, Flux upper -2.57e-04, Flux lower -2.57e-04, Flux center 1.62e+01
# INFO:root:Time 0.15, Flux left -2.61e-04, Flux right -2.61e-04, Flux upper -2.61e-04, Flux lower -2.61e-04, Flux center 1.62e+01
# INFO:root:Time 0.16, Flux left -2.65e-04, Flux right -2.65e-04, Flux upper -2.65e-04, Flux lower -2.65e-04, Flux center 1.63e+01
# INFO:root:Time 0.16, Flux left -2.69e-04, Flux right -2.69e-04, Flux upper -2.69e-04, Flux lower -2.69e-04, Flux center 1.64e+01
# INFO:root:Time 0.16, Flux left -2.73e-04, Flux right -2.73e-04, Flux upper -2.73e-04, Flux lower -2.73e-04, Flux center 1.64e+01
# INFO:root:Time 0.16, Flux left -2.77e-04, Flux right -2.77e-04, Flux upper -2.77e-04, Flux lower -2.77e-04, Flux center 1.65e+01
# INFO:root:Time 0.16, Flux left -2.80e-04, Flux right -2.80e-04, Flux upper -2.80e-04, Flux lower -2.80e-04, Flux center 1.65e+01
# INFO:root:Time 0.17, Flux left -2.84e-04, Flux right -2.84e-04, Flux upper -2.84e-04, Flux lower -2.84e-04, Flux center 1.66e+01
# INFO:root:Time 0.17, Flux left -2.87e-04, Flux right -2.87e-04, Flux upper -2.87e-04, Flux lower -2.87e-04, Flux center 1.66e+01
# INFO:root:Time 0.17, Flux left -2.90e-04, Flux right -2.90e-04, Flux upper -2.90e-04, Flux lower -2.90e-04, Flux center 1.67e+01
# INFO:root:Time 0.17, Flux left -2.94e-04, Flux right -2.94e-04, Flux upper -2.94e-04, Flux lower -2.94e-04, Flux center 1.67e+01
# INFO:root:Time 0.17, Flux left -2.97e-04, Flux right -2.97e-04, Flux upper -2.97e-04, Flux lower -2.97e-04, Flux center 1.68e+01
# INFO:root:Time 0.18, Flux left -3.00e-04, Flux right -3.00e-04, Flux upper -3.00e-04, Flux lower -3.00e-04, Flux center 1.68e+01
# INFO:root:Time 0.18, Flux left -3.03e-04, Flux right -3.03e-04, Flux upper -3.03e-04, Flux lower -3.03e-04, Flux center 1.69e+01
# INFO:root:Time 0.18, Flux left -3.06e-04, Flux right -3.06e-04, Flux upper -3.06e-04, Flux lower -3.06e-04, Flux center 1.69e+01
# INFO:root:Time 0.18, Flux left -3.09e-04, Flux right -3.09e-04, Flux upper -3.09e-04, Flux lower -3.09e-04, Flux center 1.69e+01
# INFO:root:Time 0.18, Flux left -3.12e-04, Flux right -3.12e-04, Flux upper -3.12e-04, Flux lower -3.12e-04, Flux center 1.70e+01
# INFO:root:Time 0.19, Flux left -3.15e-04, Flux right -3.15e-04, Flux upper -3.15e-04, Flux lower -3.15e-04, Flux center 1.70e+01
# INFO:root:Time 0.19, Flux left -3.18e-04, Flux right -3.18e-04, Flux upper -3.18e-04, Flux lower -3.18e-04, Flux center 1.71e+01
# INFO:root:Time 0.19, Flux left -3.21e-04, Flux right -3.21e-04, Flux upper -3.21e-04, Flux lower -3.21e-04, Flux center 1.71e+01
# INFO:root:Time 0.19, Flux left -3.23e-04, Flux right -3.23e-04, Flux upper -3.23e-04, Flux lower -3.23e-04, Flux center 1.71e+01
# INFO:root:Time 0.19, Flux left -3.26e-04, Flux right -3.26e-04, Flux upper -3.26e-04, Flux lower -3.26e-04, Flux center 1.72e+01
# INFO:root:Time 0.20, Flux left -3.28e-04, Flux right -3.28e-04, Flux upper -3.28e-04, Flux lower -3.28e-04, Flux center 1.72e+01
# INFO:root:Time 0.20, Flux left -3.31e-04, Flux right -3.31e-04, Flux upper -3.31e-04, Flux lower -3.31e-04, Flux center 1.72e+01
# INFO:root:Time 0.20, Flux left -3.33e-04, Flux right -3.33e-04, Flux upper -3.33e-04, Flux lower -3.33e-04, Flux center 1.73e+01
# INFO:root:Time 0.20, Flux left -3.36e-04, Flux right -3.36e-04, Flux upper -3.36e-04, Flux lower -3.36e-04, Flux center 1.73e+01
# INFO:root:Time 0.20, Flux left -3.38e-04, Flux right -3.38e-04, Flux upper -3.38e-04, Flux lower -3.38e-04, Flux center 1.73e+01
# INFO:root:Time 0.21, Flux left -3.40e-04, Flux right -3.40e-04, Flux upper -3.40e-04, Flux lower -3.40e-04, Flux center 1.73e+01
# INFO:root:Time 0.21, Flux left -3.42e-04, Flux right -3.42e-04, Flux upper -3.42e-04, Flux lower -3.42e-04, Flux center 1.74e+01
# INFO:root:Time 0.21, Flux left -3.44e-04, Flux right -3.44e-04, Flux upper -3.44e-04, Flux lower -3.44e-04, Flux center 1.74e+01
# INFO:root:Time 0.21, Flux left -3.47e-04, Flux right -3.47e-04, Flux upper -3.47e-04, Flux lower -3.47e-04, Flux center 1.74e+01
# INFO:root:Time 0.21, Flux left -3.49e-04, Flux right -3.49e-04, Flux upper -3.49e-04, Flux lower -3.49e-04, Flux center 1.75e+01
# INFO:root:Time 0.22, Flux left -3.51e-04, Flux right -3.51e-04, Flux upper -3.51e-04, Flux lower -3.51e-04, Flux center 1.75e+01
# INFO:root:Time 0.22, Flux left -3.53e-04, Flux right -3.53e-04, Flux upper -3.53e-04, Flux lower -3.53e-04, Flux center 1.75e+01
# INFO:root:Time 0.22, Flux left -3.54e-04, Flux right -3.54e-04, Flux upper -3.54e-04, Flux lower -3.54e-04, Flux center 1.75e+01
# INFO:root:Time 0.22, Flux left -3.56e-04, Flux right -3.56e-04, Flux upper -3.56e-04, Flux lower -3.56e-04, Flux center 1.76e+01
# INFO:root:Time 0.22, Flux left -3.58e-04, Flux right -3.58e-04, Flux upper -3.58e-04, Flux lower -3.58e-04, Flux center 1.76e+01
# INFO:root:Time 0.23, Flux left -3.60e-04, Flux right -3.60e-04, Flux upper -3.60e-04, Flux lower -3.60e-04, Flux center 1.76e+01
# INFO:root:Time 0.23, Flux left -3.62e-04, Flux right -3.62e-04, Flux upper -3.62e-04, Flux lower -3.62e-04, Flux center 1.76e+01
# INFO:root:Time 0.23, Flux left -3.63e-04, Flux right -3.63e-04, Flux upper -3.63e-04, Flux lower -3.63e-04, Flux center 1.76e+01
# INFO:root:Time 0.23, Flux left -3.65e-04, Flux right -3.65e-04, Flux upper -3.65e-04, Flux lower -3.65e-04, Flux center 1.77e+01
# INFO:root:Time 0.23, Flux left -3.66e-04, Flux right -3.66e-04, Flux upper -3.66e-04, Flux lower -3.66e-04, Flux center 1.77e+01
# INFO:root:Time 0.24, Flux left -3.68e-04, Flux right -3.68e-04, Flux upper -3.68e-04, Flux lower -3.68e-04, Flux center 1.77e+01
# INFO:root:Time 0.24, Flux left -3.69e-04, Flux right -3.69e-04, Flux upper -3.69e-04, Flux lower -3.69e-04, Flux center 1.77e+01
# INFO:root:Time 0.24, Flux left -3.71e-04, Flux right -3.71e-04, Flux upper -3.71e-04, Flux lower -3.71e-04, Flux center 1.77e+01
# INFO:root:Time 0.24, Flux left -3.72e-04, Flux right -3.72e-04, Flux upper -3.72e-04, Flux lower -3.72e-04, Flux center 1.77e+01
# INFO:root:Time 0.24, Flux left -3.74e-04, Flux right -3.74e-04, Flux upper -3.74e-04, Flux lower -3.74e-04, Flux center 1.78e+01
# INFO:root:Time 0.25, Flux left -3.75e-04, Flux right -3.75e-04, Flux upper -3.75e-04, Flux lower -3.75e-04, Flux center 1.78e+01
# INFO:root:Time 0.25, Flux left -3.76e-04, Flux right -3.76e-04, Flux upper -3.76e-04, Flux lower -3.76e-04, Flux center 1.78e+01
# INFO:root:Time 0.25, Flux left -3.78e-04, Flux right -3.78e-04, Flux upper -3.78e-04, Flux lower -3.78e-04, Flux center 1.78e+01
# INFO:root:Time 0.25, Flux left -3.79e-04, Flux right -3.79e-04, Flux upper -3.79e-04, Flux lower -3.79e-04, Flux center 1.78e+01
# INFO:root:Time 0.25, Flux left -3.80e-04, Flux right -3.80e-04, Flux upper -3.80e-04, Flux lower -3.80e-04, Flux center 1.78e+01
# INFO:root:Time 0.26, Flux left -3.81e-04, Flux right -3.81e-04, Flux upper -3.81e-04, Flux lower -3.81e-04, Flux center 1.79e+01
# INFO:root:Time 0.26, Flux left -3.82e-04, Flux right -3.82e-04, Flux upper -3.82e-04, Flux lower -3.82e-04, Flux center 1.79e+01
# INFO:root:Time 0.26, Flux left -3.84e-04, Flux right -3.84e-04, Flux upper -3.84e-04, Flux lower -3.84e-04, Flux center 1.79e+01
# INFO:root:Time 0.26, Flux left -3.85e-04, Flux right -3.85e-04, Flux upper -3.85e-04, Flux lower -3.85e-04, Flux center 1.79e+01
# INFO:root:Time 0.26, Flux left -3.86e-04, Flux right -3.86e-04, Flux upper -3.86e-04, Flux lower -3.86e-04, Flux center 1.79e+01
# INFO:root:Time 0.27, Flux left -3.87e-04, Flux right -3.87e-04, Flux upper -3.87e-04, Flux lower -3.87e-04, Flux center 1.79e+01
# INFO:root:Time 0.27, Flux left -3.88e-04, Flux right -3.88e-04, Flux upper -3.88e-04, Flux lower -3.88e-04, Flux center 1.79e+01
# INFO:root:Time 0.27, Flux left -3.89e-04, Flux right -3.89e-04, Flux upper -3.89e-04, Flux lower -3.89e-04, Flux center 1.79e+01
# INFO:root:Time 0.27, Flux left -3.90e-04, Flux right -3.90e-04, Flux upper -3.90e-04, Flux lower -3.90e-04, Flux center 1.80e+01
# INFO:root:Time 0.27, Flux left -3.91e-04, Flux right -3.91e-04, Flux upper -3.91e-04, Flux lower -3.91e-04, Flux center 1.80e+01
# INFO:root:Time 0.28, Flux left -3.92e-04, Flux right -3.92e-04, Flux upper -3.92e-04, Flux lower -3.92e-04, Flux center 1.80e+01
# INFO:root:Time 0.28, Flux left -3.92e-04, Flux right -3.92e-04, Flux upper -3.92e-04, Flux lower -3.92e-04, Flux center 1.80e+01
# INFO:root:Time 0.28, Flux left -3.93e-04, Flux right -3.93e-04, Flux upper -3.93e-04, Flux lower -3.93e-04, Flux center 1.80e+01
# INFO:root:Time 0.28, Flux left -3.94e-04, Flux right -3.94e-04, Flux upper -3.94e-04, Flux lower -3.94e-04, Flux center 1.80e+01
# INFO:root:Time 0.28, Flux left -3.95e-04, Flux right -3.95e-04, Flux upper -3.95e-04, Flux lower -3.95e-04, Flux center 1.80e+01
# INFO:root:Time 0.29, Flux left -3.96e-04, Flux right -3.96e-04, Flux upper -3.96e-04, Flux lower -3.96e-04, Flux center 1.80e+01
# INFO:root:Time 0.29, Flux left -3.97e-04, Flux right -3.97e-04, Flux upper -3.97e-04, Flux lower -3.97e-04, Flux center 1.80e+01
# INFO:root:Time 0.29, Flux left -3.97e-04, Flux right -3.97e-04, Flux upper -3.97e-04, Flux lower -3.97e-04, Flux center 1.80e+01
# INFO:root:Time 0.29, Flux left -3.98e-04, Flux right -3.98e-04, Flux upper -3.98e-04, Flux lower -3.98e-04, Flux center 1.81e+01
# INFO:root:Time 0.29, Flux left -3.99e-04, Flux right -3.99e-04, Flux upper -3.99e-04, Flux lower -3.99e-04, Flux center 1.81e+01
# INFO:root:Time 0.30, Flux left -3.99e-04, Flux right -3.99e-04, Flux upper -3.99e-04, Flux lower -3.99e-04, Flux center 1.81e+01
# INFO:root:Time 0.30, Flux left -4.00e-04, Flux right -4.00e-04, Flux upper -4.00e-04, Flux lower -4.00e-04, Flux center 1.81e+01
# INFO:root:Time 0.30, Flux left -4.01e-04, Flux right -4.01e-04, Flux upper -4.01e-04, Flux lower -4.01e-04, Flux center 1.81e+01
# INFO:root:Time 0.30, Flux left -4.01e-04, Flux right -4.01e-04, Flux upper -4.01e-04, Flux lower -4.01e-04, Flux center 1.81e+01
# INFO:root:Relative mass flow change 1.99859e-05 converged within relatvie tolerance 1e-05
# INFO:wslink.backends.aiohttp:awaiting runner setup
# INFO:wslink.backends.aiohttp:awaiting site startup
# INFO:wslink.backends.aiohttp:Print WSLINK_READY_MSG
# INFO:wslink.backends.aiohttp:Schedule auto shutdown with timout 0
# INFO:wslink.backends.aiohttp:awaiting running future
# Widget(value='<iframe src="http://localhost:41155/index.html?ui=P_0x7f4dbffcfe00_0&reconnect=auto" class="pyvi…
# INFO:root:RUN 1: pressure 1250
# INFO:root:facets with tag 3: [  0   2   6  13  26  32  45  58  62  77  94 113 124 146 149 156 185 186
#  191 205]
# INFO:root:number of facets with tag 3: 20
# INFO:root:Time 0.06, Flux left -7.26e-05, Flux right -7.26e-05, Flux upper -7.26e-05, Flux lower -7.26e-05, Flux center 1.36e+01
# INFO:root:Time 0.07, Flux left -7.90e-05, Flux right -7.90e-05, Flux upper -7.90e-05, Flux lower -7.90e-05, Flux center 1.38e+01
# INFO:root:Time 0.07, Flux left -8.59e-05, Flux right -8.59e-05, Flux upper -8.59e-05, Flux lower -8.59e-05, Flux center 1.41e+01
# INFO:root:Time 0.07, Flux left -9.33e-05, Flux right -9.33e-05, Flux upper -9.33e-05, Flux lower -9.33e-05, Flux center 1.43e+01
# INFO:root:Time 0.07, Flux left -1.01e-04, Flux right -1.01e-04, Flux upper -1.01e-04, Flux lower -1.01e-04, Flux center 1.45e+01
# INFO:root:Time 0.07, Flux left -1.09e-04, Flux right -1.09e-04, Flux upper -1.09e-04, Flux lower -1.09e-04, Flux center 1.48e+01
# INFO:root:Time 0.08, Flux left -1.18e-04, Flux right -1.18e-04, Flux upper -1.18e-04, Flux lower -1.18e-04, Flux center 1.50e+01
# INFO:root:Time 0.08, Flux left -1.27e-04, Flux right -1.27e-04, Flux upper -1.27e-04, Flux lower -1.27e-04, Flux center 1.52e+01
# INFO:root:Time 0.08, Flux left -1.36e-04, Flux right -1.36e-04, Flux upper -1.36e-04, Flux lower -1.36e-04, Flux center 1.54e+01
# INFO:root:Time 0.08, Flux left -1.46e-04, Flux right -1.46e-04, Flux upper -1.46e-04, Flux lower -1.46e-04, Flux center 1.56e+01
# INFO:root:Time 0.08, Flux left -1.55e-04, Flux right -1.55e-04, Flux upper -1.55e-04, Flux lower -1.55e-04, Flux center 1.58e+01
# INFO:root:Time 0.09, Flux left -1.65e-04, Flux right -1.65e-04, Flux upper -1.65e-04, Flux lower -1.65e-04, Flux center 1.60e+01
# INFO:root:Time 0.09, Flux left -1.75e-04, Flux right -1.75e-04, Flux upper -1.75e-04, Flux lower -1.75e-04, Flux center 1.62e+01
# INFO:root:Time 0.09, Flux left -1.85e-04, Flux right -1.85e-04, Flux upper -1.85e-04, Flux lower -1.85e-04, Flux center 1.64e+01
# INFO:root:Time 0.09, Flux left -1.95e-04, Flux right -1.95e-04, Flux upper -1.95e-04, Flux lower -1.95e-04, Flux center 1.66e+01
# INFO:root:Time 0.09, Flux left -2.06e-04, Flux right -2.06e-04, Flux upper -2.06e-04, Flux lower -2.06e-04, Flux center 1.67e+01
# INFO:root:Time 0.10, Flux left -2.16e-04, Flux right -2.16e-04, Flux upper -2.16e-04, Flux lower -2.16e-04, Flux center 1.69e+01
# INFO:root:Time 0.10, Flux left -2.26e-04, Flux right -2.26e-04, Flux upper -2.26e-04, Flux lower -2.26e-04, Flux center 1.71e+01
# INFO:root:Time 0.10, Flux left -2.36e-04, Flux right -2.36e-04, Flux upper -2.36e-04, Flux lower -2.36e-04, Flux center 1.72e+01
# INFO:root:Time 0.10, Flux left -2.46e-04, Flux right -2.46e-04, Flux upper -2.46e-04, Flux lower -2.46e-04, Flux center 1.74e+01
# INFO:root:Time 0.10, Flux left -2.56e-04, Flux right -2.56e-04, Flux upper -2.56e-04, Flux lower -2.56e-04, Flux center 1.75e+01
# INFO:root:Time 0.11, Flux left -2.66e-04, Flux right -2.66e-04, Flux upper -2.66e-04, Flux lower -2.66e-04, Flux center 1.77e+01
# INFO:root:Time 0.11, Flux left -2.76e-04, Flux right -2.76e-04, Flux upper -2.76e-04, Flux lower -2.76e-04, Flux center 1.78e+01
# INFO:root:Time 0.11, Flux left -2.86e-04, Flux right -2.86e-04, Flux upper -2.86e-04, Flux lower -2.86e-04, Flux center 1.80e+01
# INFO:root:Time 0.11, Flux left -2.96e-04, Flux right -2.96e-04, Flux upper -2.96e-04, Flux lower -2.96e-04, Flux center 1.81e+01
# INFO:root:Time 0.11, Flux left -3.06e-04, Flux right -3.06e-04, Flux upper -3.06e-04, Flux lower -3.06e-04, Flux center 1.82e+01
# INFO:root:Time 0.12, Flux left -3.16e-04, Flux right -3.16e-04, Flux upper -3.16e-04, Flux lower -3.16e-04, Flux center 1.83e+01
# INFO:root:Time 0.12, Flux left -3.25e-04, Flux right -3.25e-04, Flux upper -3.25e-04, Flux lower -3.25e-04, Flux center 1.85e+01
# INFO:root:Time 0.12, Flux left -3.35e-04, Flux right -3.35e-04, Flux upper -3.35e-04, Flux lower -3.35e-04, Flux center 1.86e+01
# INFO:root:Time 0.12, Flux left -3.44e-04, Flux right -3.44e-04, Flux upper -3.44e-04, Flux lower -3.44e-04, Flux center 1.87e+01
# INFO:root:Time 0.12, Flux left -3.53e-04, Flux right -3.53e-04, Flux upper -3.53e-04, Flux lower -3.53e-04, Flux center 1.88e+01
# INFO:root:Time 0.13, Flux left -3.62e-04, Flux right -3.62e-04, Flux upper -3.62e-04, Flux lower -3.62e-04, Flux center 1.89e+01
# INFO:root:Time 0.13, Flux left -3.71e-04, Flux right -3.71e-04, Flux upper -3.71e-04, Flux lower -3.71e-04, Flux center 1.90e+01
# INFO:root:Time 0.13, Flux left -3.80e-04, Flux right -3.80e-04, Flux upper -3.80e-04, Flux lower -3.80e-04, Flux center 1.91e+01
# INFO:root:Time 0.13, Flux left -3.89e-04, Flux right -3.89e-04, Flux upper -3.89e-04, Flux lower -3.89e-04, Flux center 1.92e+01
# INFO:root:Time 0.13, Flux left -3.97e-04, Flux right -3.97e-04, Flux upper -3.97e-04, Flux lower -3.97e-04, Flux center 1.93e+01
# INFO:root:Time 0.14, Flux left -4.06e-04, Flux right -4.06e-04, Flux upper -4.06e-04, Flux lower -4.06e-04, Flux center 1.94e+01
# INFO:root:Time 0.14, Flux left -4.14e-04, Flux right -4.14e-04, Flux upper -4.14e-04, Flux lower -4.14e-04, Flux center 1.95e+01
# INFO:root:Time 0.14, Flux left -4.22e-04, Flux right -4.22e-04, Flux upper -4.22e-04, Flux lower -4.22e-04, Flux center 1.96e+01
# INFO:root:Time 0.14, Flux left -4.30e-04, Flux right -4.30e-04, Flux upper -4.30e-04, Flux lower -4.30e-04, Flux center 1.97e+01
# INFO:root:Time 0.14, Flux left -4.38e-04, Flux right -4.38e-04, Flux upper -4.38e-04, Flux lower -4.38e-04, Flux center 1.98e+01
# INFO:root:Time 0.15, Flux left -4.46e-04, Flux right -4.46e-04, Flux upper -4.46e-04, Flux lower -4.46e-04, Flux center 1.99e+01
# INFO:root:Time 0.15, Flux left -4.53e-04, Flux right -4.53e-04, Flux upper -4.53e-04, Flux lower -4.53e-04, Flux center 1.99e+01
# INFO:root:Time 0.15, Flux left -4.61e-04, Flux right -4.61e-04, Flux upper -4.61e-04, Flux lower -4.61e-04, Flux center 2.00e+01
# INFO:root:Time 0.15, Flux left -4.68e-04, Flux right -4.68e-04, Flux upper -4.68e-04, Flux lower -4.68e-04, Flux center 2.01e+01
# INFO:root:Time 0.15, Flux left -4.75e-04, Flux right -4.75e-04, Flux upper -4.75e-04, Flux lower -4.75e-04, Flux center 2.02e+01
# INFO:root:Time 0.16, Flux left -4.82e-04, Flux right -4.82e-04, Flux upper -4.82e-04, Flux lower -4.82e-04, Flux center 2.02e+01
# INFO:root:Time 0.16, Flux left -4.89e-04, Flux right -4.89e-04, Flux upper -4.89e-04, Flux lower -4.89e-04, Flux center 2.03e+01
# INFO:root:Time 0.16, Flux left -4.96e-04, Flux right -4.96e-04, Flux upper -4.96e-04, Flux lower -4.96e-04, Flux center 2.04e+01
# INFO:root:Time 0.16, Flux left -5.03e-04, Flux right -5.03e-04, Flux upper -5.03e-04, Flux lower -5.03e-04, Flux center 2.04e+01
# INFO:root:Time 0.16, Flux left -5.09e-04, Flux right -5.09e-04, Flux upper -5.09e-04, Flux lower -5.09e-04, Flux center 2.05e+01
# INFO:root:Time 0.17, Flux left -5.15e-04, Flux right -5.15e-04, Flux upper -5.15e-04, Flux lower -5.15e-04, Flux center 2.06e+01
# INFO:root:Time 0.17, Flux left -5.22e-04, Flux right -5.22e-04, Flux upper -5.22e-04, Flux lower -5.22e-04, Flux center 2.06e+01
# INFO:root:Time 0.17, Flux left -5.28e-04, Flux right -5.28e-04, Flux upper -5.28e-04, Flux lower -5.28e-04, Flux center 2.07e+01
# INFO:root:Time 0.17, Flux left -5.33e-04, Flux right -5.33e-04, Flux upper -5.33e-04, Flux lower -5.33e-04, Flux center 2.07e+01
# INFO:root:Time 0.17, Flux left -5.39e-04, Flux right -5.39e-04, Flux upper -5.39e-04, Flux lower -5.39e-04, Flux center 2.08e+01
# INFO:root:Time 0.18, Flux left -5.45e-04, Flux right -5.45e-04, Flux upper -5.45e-04, Flux lower -5.45e-04, Flux center 2.08e+01
# INFO:root:Time 0.18, Flux left -5.50e-04, Flux right -5.50e-04, Flux upper -5.50e-04, Flux lower -5.50e-04, Flux center 2.09e+01
# INFO:root:Time 0.18, Flux left -5.56e-04, Flux right -5.56e-04, Flux upper -5.56e-04, Flux lower -5.56e-04, Flux center 2.09e+01
# INFO:root:Time 0.18, Flux left -5.61e-04, Flux right -5.61e-04, Flux upper -5.61e-04, Flux lower -5.61e-04, Flux center 2.10e+01
# INFO:root:Time 0.22, Flux left -6.46e-04, Flux right -6.46e-04, Flux upper -6.46e-04, Flux lower -6.46e-04, Flux center 2.17e+01
# INFO:root:Time 0.23, Flux left -6.49e-04, Flux right -6.49e-04, Flux upper -6.49e-04, Flux lower -6.49e-04, Flux center 2.18e+01
# INFO:root:Time 0.23, Flux left -6.52e-04, Flux right -6.52e-04, Flux upper -6.52e-04, Flux lower -6.52e-04, Flux center 2.18e+01
# INFO:root:Time 0.23, Flux left -6.54e-04, Flux right -6.54e-04, Flux upper -6.54e-04, Flux lower -6.54e-04, Flux center 2.18e+01
# INFO:root:Time 0.23, Flux left -6.57e-04, Flux right -6.57e-04, Flux upper -6.57e-04, Flux lower -6.57e-04, Flux center 2.18e+01
# INFO:root:Time 0.23, Flux left -6.60e-04, Flux right -6.60e-04, Flux upper -6.60e-04, Flux lower -6.60e-04, Flux center 2.19e+01
# INFO:root:Time 0.24, Flux left -6.63e-04, Flux right -6.63e-04, Flux upper -6.63e-04, Flux lower -6.63e-04, Flux center 2.19e+01
# INFO:root:Time 0.24, Flux left -6.65e-04, Flux right -6.65e-04, Flux upper -6.65e-04, Flux lower -6.65e-04, Flux center 2.19e+01
# INFO:root:Time 0.24, Flux left -6.68e-04, Flux right -6.68e-04, Flux upper -6.68e-04, Flux lower -6.68e-04, Flux center 2.19e+01
# INFO:root:Time 0.24, Flux left -6.70e-04, Flux right -6.70e-04, Flux upper -6.70e-04, Flux lower -6.70e-04, Flux center 2.19e+01
# INFO:root:Time 0.24, Flux left -6.72e-04, Flux right -6.72e-04, Flux upper -6.72e-04, Flux lower -6.72e-04, Flux center 2.20e+01
# INFO:root:Time 0.25, Flux left -6.75e-04, Flux right -6.75e-04, Flux upper -6.75e-04, Flux lower -6.75e-04, Flux center 2.20e+01
# INFO:root:Time 0.25, Flux left -6.77e-04, Flux right -6.77e-04, Flux upper -6.77e-04, Flux lower -6.77e-04, Flux center 2.20e+01
# INFO:root:Time 0.25, Flux left -6.79e-04, Flux right -6.79e-04, Flux upper -6.79e-04, Flux lower -6.79e-04, Flux center 2.20e+01
# INFO:root:Time 0.25, Flux left -6.81e-04, Flux right -6.81e-04, Flux upper -6.81e-04, Flux lower -6.81e-04, Flux center 2.20e+01
# INFO:root:Time 0.25, Flux left -6.83e-04, Flux right -6.83e-04, Flux upper -6.83e-04, Flux lower -6.83e-04, Flux center 2.20e+01
# INFO:root:Time 0.26, Flux left -6.85e-04, Flux right -6.85e-04, Flux upper -6.85e-04, Flux lower -6.85e-04, Flux center 2.21e+01
# INFO:root:Time 0.26, Flux left -6.87e-04, Flux right -6.87e-04, Flux upper -6.87e-04, Flux lower -6.87e-04, Flux center 2.21e+01
# INFO:root:Time 0.26, Flux left -6.89e-04, Flux right -6.89e-04, Flux upper -6.89e-04, Flux lower -6.89e-04, Flux center 2.21e+01
# INFO:root:Time 0.26, Flux left -6.91e-04, Flux right -6.91e-04, Flux upper -6.91e-04, Flux lower -6.91e-04, Flux center 2.21e+01
# INFO:root:Time 0.26, Flux left -6.92e-04, Flux right -6.92e-04, Flux upper -6.92e-04, Flux lower -6.92e-04, Flux center 2.21e+01
# INFO:root:Time 0.27, Flux left -6.94e-04, Flux right -6.94e-04, Flux upper -6.94e-04, Flux lower -6.94e-04, Flux center 2.21e+01
# INFO:root:Time 0.27, Flux left -6.96e-04, Flux right -6.96e-04, Flux upper -6.96e-04, Flux lower -6.96e-04, Flux center 2.22e+01
# INFO:root:Time 0.27, Flux left -6.97e-04, Flux right -6.97e-04, Flux upper -6.97e-04, Flux lower -6.97e-04, Flux center 2.22e+01
# INFO:root:Time 0.27, Flux left -6.99e-04, Flux right -6.99e-04, Flux upper -6.99e-04, Flux lower -6.99e-04, Flux center 2.22e+01
# INFO:root:Time 0.27, Flux left -7.01e-04, Flux right -7.01e-04, Flux upper -7.01e-04, Flux lower -7.01e-04, Flux center 2.22e+01
# INFO:root:Time 0.28, Flux left -7.02e-04, Flux right -7.02e-04, Flux upper -7.02e-04, Flux lower -7.02e-04, Flux center 2.22e+01
# INFO:root:Time 0.28, Flux left -7.04e-04, Flux right -7.04e-04, Flux upper -7.04e-04, Flux lower -7.04e-04, Flux center 2.22e+01
# INFO:root:Time 0.28, Flux left -7.05e-04, Flux right -7.05e-04, Flux upper -7.05e-04, Flux lower -7.05e-04, Flux center 2.22e+01
# INFO:root:Time 0.28, Flux left -7.06e-04, Flux right -7.06e-04, Flux upper -7.06e-04, Flux lower -7.06e-04, Flux center 2.22e+01
# INFO:root:Time 0.28, Flux left -7.08e-04, Flux right -7.08e-04, Flux upper -7.08e-04, Flux lower -7.08e-04, Flux center 2.22e+01
# INFO:root:Time 0.29, Flux left -7.09e-04, Flux right -7.09e-04, Flux upper -7.09e-04, Flux lower -7.09e-04, Flux center 2.23e+01
# INFO:root:Time 0.29, Flux left -7.10e-04, Flux right -7.10e-04, Flux upper -7.10e-04, Flux lower -7.10e-04, Flux center 2.23e+01
# INFO:root:Time 0.29, Flux left -7.11e-04, Flux right -7.11e-04, Flux upper -7.11e-04, Flux lower -7.11e-04, Flux center 2.23e+01
# INFO:root:Time 0.29, Flux left -7.13e-04, Flux right -7.13e-04, Flux upper -7.13e-04, Flux lower -7.13e-04, Flux center 2.23e+01
# INFO:root:Time 0.29, Flux left -7.14e-04, Flux right -7.14e-04, Flux upper -7.14e-04, Flux lower -7.14e-04, Flux center 2.23e+01
# INFO:root:Relative mass flow change 1.99912e-05 converged within relatvie tolerance 1e-05
# Widget(value='<iframe src="http://localhost:41155/index.html?ui=P_0x7f4ced333890_1&reconnect=auto" class="pyvi…
# INFO:root:RUN 2: pressure 1500
# INFO:root:facets with tag 3: [  0   2   6  13  26  32  45  58  62  77  94 113 124 146 149 156 185 186
#  191 205]
# INFO:root:number of facets with tag 3: 20
# INFO:root:facets with tag 2: [3916 3948 3949 3980 4034 4054 4083 4099 4100 4118 4139 4140 4152 4168
#  4169 4170 4171 4172 4175 4176]
# INFO:root:number of facets with tag 2: 20
# INFO:root:facets with tag 1: [ 188  196  274  345  417  488  558  627  694  762  832  900  968 1038
#  1107 1171 1238 1306 1379 1445 1513 1582 1650 1713 1726 1780 1840 1893
#  1949 2000 2051 2076 2122 2189 2238 2287 2336 2387 2439 2495 2555 2618
#  2686 2699 2760 2827 2857 2922 2989 3056 3124 3193 3260 3327 3395 3465
#  3535 3605 3676 3746 3818 3889 3951 4013 4064 4108 4142]
# INFO:root:number of facets with tag 1: 67
# INFO:root:facets with tag 4: [ 285  340  359  412  444  484  518  582  654  724  795  867  898  942
#  1013 1084 1151 1218 1286 1358 1425 1494 1559 1629 1693 1764 1827 1887
#  1944 1995 2047 2096 2142 2187 2234 2285 2334 2385 2437 2490 2550 2613
#  2684 2756 2826 2897 2964 3033 3101 3169 3241 3309 3380 3444 3511 3578
#  3644 3710 3780 3850]
# INFO:root:number of facets with tag 4: 60
# WARNING:py.warnings:/tmp/ipykernel_37857/1626486534.py:274: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   mass_flow_through_cross_section = np.trapz(y=velocity_profile[0], x=y_grid)
#
# INFO:root:Time 0.00, Flux left 1.90e-04, Flux right 1.90e-04, Flux upper 1.90e-04, Flux lower 1.90e-04, Flux center 4.54e-02
# INFO:root:Time 0.00, Flux left 1.39e-05, Flux right 1.39e-05, Flux upper 1.39e-05, Flux lower 1.39e-05, Flux center 8.77e-01
# INFO:root:Time 0.00, Flux left 1.62e-05, Flux right 1.62e-05, Flux upper 1.62e-05, Flux lower 1.62e-05, Flux center 1.65e+00
# INFO:root:Time 0.01, Flux left 1.74e-05, Flux right 1.74e-05, Flux upper 1.74e-05, Flux lower 1.74e-05, Flux center 2.39e+00
# INFO:root:Time 0.01, Flux left 1.72e-05, Flux right 1.72e-05, Flux upper 1.72e-05, Flux lower 1.72e-05, Flux center 3.10e+00
# INFO:root:Time 0.01, Flux left 1.60e-05, Flux right 1.60e-05, Flux upper 1.60e-05, Flux lower 1.60e-05, Flux center 3.78e+00
# INFO:root:Time 0.01, Flux left 1.42e-05, Flux right 1.42e-05, Flux upper 1.42e-05, Flux lower 1.42e-05, Flux center 4.44e+00
# INFO:root:Time 0.01, Flux left 1.20e-05, Flux right 1.20e-05, Flux upper 1.20e-05, Flux lower 1.20e-05, Flux center 5.08e+00
# INFO:root:Time 0.02, Flux left 9.55e-06, Flux right 9.55e-06, Flux upper 9.55e-06, Flux lower 9.55e-06, Flux center 5.70e+00
# INFO:root:Time 0.02, Flux left 6.84e-06, Flux right 6.84e-06, Flux upper 6.84e-06, Flux lower 6.84e-06, Flux center 6.29e+00
# INFO:root:Time 0.02, Flux left 3.97e-06, Flux right 3.97e-06, Flux upper 3.97e-06, Flux lower 3.97e-06, Flux center 6.88e+00
# INFO:root:Time 0.02, Flux left 9.82e-07, Flux right 9.82e-07, Flux upper 9.82e-07, Flux lower 9.82e-07, Flux center 7.44e+00
# INFO:root:Time 0.02, Flux left -2.10e-06, Flux right -2.10e-06, Flux upper -2.10e-06, Flux lower -2.10e-06, Flux center 7.99e+00
# INFO:root:Time 0.07, Flux left -1.23e-04, Flux right -1.23e-04, Flux upper -1.23e-04, Flux lower -1.23e-04, Flux center 1.66e+01
# ...
# INFO:root:number of facets with tag 1: 67
# INFO:root:facets with tag 4: [ 285  340  359  412  444  484  518  582  654  724  795  867  898  942
#  1013 1084 1151 1218 1286 1358 1425 1494 1559 1629 1693 1764 1827 1887
#  1944 1995 2047 2096 2142 2187 2234 2285 2334 2385 2437 2490 2550 2613
#  2684 2756 2826 2897 2964 3033 3101 3169 3241 3309 3380 3444 3511 3578
#  3644 3710 3780 3850]
# INFO:root:number of facets with tag 4: 60
# WARNING:py.warnings:/tmp/ipykernel_37857/1626486534.py:274: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   mass_flow_through_cross_section = np.trapz(y=velocity_profile[0], x=y_grid)
#
# INFO:root:Time 0.00, Flux left 6.02e-04, Flux right 6.02e-04, Flux upper 6.02e-04, Flux lower 6.02e-04, Flux center 1.44e-01
# INFO:root:Time 0.00, Flux left 9.66e-05, Flux right 9.66e-05, Flux upper 9.66e-05, Flux lower 9.66e-05, Flux center 2.78e+00
# INFO:root:Time 0.00, Flux left 1.14e-04, Flux right 1.14e-04, Flux upper 1.14e-04, Flux lower 1.14e-04, Flux center 5.24e+00
# INFO:root:Time 0.01, Flux left 1.24e-04, Flux right 1.24e-04, Flux upper 1.24e-04, Flux lower 1.24e-04, Flux center 7.58e+00
# INFO:root:Time 0.01, Flux left 1.27e-04, Flux right 1.27e-04, Flux upper 1.27e-04, Flux lower 1.27e-04, Flux center 9.82e+00
# INFO:root:Time 0.01, Flux left 1.27e-04, Flux right 1.27e-04, Flux upper 1.27e-04, Flux lower 1.27e-04, Flux center 1.20e+01
# INFO:root:Time 0.01, Flux left 1.23e-04, Flux right 1.23e-04, Flux upper 1.23e-04, Flux lower 1.23e-04, Flux center 1.41e+01
# INFO:root:Time 0.01, Flux left 1.18e-04, Flux right 1.18e-04, Flux upper 1.18e-04, Flux lower 1.18e-04, Flux center 1.61e+01
# INFO:root:Time 0.02, Flux left 1.11e-04, Flux right 1.11e-04, Flux upper 1.11e-04, Flux lower 1.11e-04, Flux center 1.80e+01
# INFO:root:Time 0.02, Flux left 1.03e-04, Flux right 1.03e-04, Flux upper 1.03e-04, Flux lower 1.03e-04, Flux center 1.99e+01
# INFO:root:Time 0.02, Flux left 9.40e-05, Flux right 9.40e-05, Flux upper 9.40e-05, Flux lower 9.40e-05, Flux center 2.17e+01
# INFO:root:Time 0.02, Flux left 8.32e-05, Flux right 8.32e-05, Flux upper 8.32e-05, Flux lower 8.32e-05, Flux center 2.35e+01
# INFO:root:Time 0.02, Flux left 7.01e-05, Flux right 7.01e-05, Flux upper 7.01e-05, Flux lower 7.01e-05, Flux center 2.52e+01
# INFO:root:Time 0.03, Flux left 5.35e-05, Flux right 5.35e-05, Flux upper 5.35e-05, Flux lower 5.35e-05, Flux center 2.69e+01
# INFO:root:Time 0.03, Flux left 3.12e-05, Flux right 3.12e-05, Flux upper 3.12e-05, Flux lower 3.12e-05, Flux center 2.85e+01
# INFO:root:Time 0.03, Flux left -8.87e-07, Flux right -8.87e-07, Flux upper -8.87e-07, Flux lower -8.87e-07, Flux center 3.00e+01
# INFO:root:Time 0.03, Flux left -4.94e-05, Flux right -4.94e-05, Flux upper -4.94e-05, Flux lower -4.94e-05, Flux center 3.15e+01
# INFO:root:Time 0.03, Flux left -1.23e-04, Flux right -1.23e-04, Flux upper -1.23e-04, Flux lower -1.23e-04, Flux center 3.30e+01
# INFO:root:Time 0.04, Flux left -2.32e-04, Flux right -2.32e-04, Flux upper -2.32e-04, Flux lower -2.32e-04, Flux center 3.44e+01
# INFO:root:Time 0.04, Flux left -3.85e-04, Flux right -3.85e-04, Flux upper -3.85e-04, Flux lower -3.85e-04, Flux center 3.58e+01
# INFO:root:Time 0.04, Flux left -5.87e-04, Flux right -5.87e-04, Flux upper -5.87e-04, Flux lower -5.87e-04, Flux center 3.71e+01
# INFO:root:Time 0.04, Flux left -8.36e-04, Flux right -8.36e-04, Flux upper -8.36e-04, Flux lower -8.36e-04, Flux center 3.84e+01
# INFO:root:Time 0.04, Flux left -1.13e-03, Flux right -1.13e-03, Flux upper -1.13e-03, Flux lower -1.13e-03, Flux center 3.96e+01
# INFO:root:Time 0.05, Flux left -1.45e-03, Flux right -1.45e-03, Flux upper -1.45e-03, Flux lower -1.45e-03, Flux center 4.08e+01
# INFO:root:Time 0.05, Flux left -1.78e-03, Flux right -1.78e-03, Flux upper -1.78e-03, Flux lower -1.78e-03, Flux center 4.20e+01
# INFO:root:Time 0.05, Flux left -2.12e-03, Flux right -2.12e-03, Flux upper -2.12e-03, Flux lower -2.12e-03, Flux center 4.31e+01
# INFO:root:Time 0.05, Flux left -2.45e-03, Flux right -2.45e-03, Flux upper -2.45e-03, Flux lower -2.45e-03, Flux center 4.41e+01
# INFO:root:Time 0.05, Flux left -2.77e-03, Flux right -2.77e-03, Flux upper -2.77e-03, Flux lower -2.77e-03, Flux center 4.52e+01
# INFO:root:Time 0.06, Flux left -3.07e-03, Flux right -3.07e-03, Flux upper -3.07e-03, Flux lower -3.07e-03, Flux center 4.62e+01
# INFO:root:Time 0.06, Flux left -3.36e-03, Flux right -3.36e-03, Flux upper -3.36e-03, Flux lower -3.36e-03, Flux center 4.71e+01
# INFO:root:Time 0.06, Flux left -3.63e-03, Flux right -3.63e-03, Flux upper -3.63e-03, Flux lower -3.63e-03, Flux center 4.81e+01
# INFO:root:Time 0.06, Flux left -3.90e-03, Flux right -3.90e-03, Flux upper -3.90e-03, Flux lower -3.90e-03, Flux center 4.90e+01
# INFO:root:Time 0.06, Flux left -4.16e-03, Flux right -4.16e-03, Flux upper -4.16e-03, Flux lower -4.16e-03, Flux center 4.98e+01
# INFO:root:Time 0.07, Flux left -4.41e-03, Flux right -4.41e-03, Flux upper -4.41e-03, Flux lower -4.41e-03, Flux center 5.07e+01
# INFO:root:Time 0.07, Flux left -4.66e-03, Flux right -4.66e-03, Flux upper -4.66e-03, Flux lower -4.66e-03, Flux center 5.15e+01
# INFO:root:Time 0.07, Flux left -4.91e-03, Flux right -4.91e-03, Flux upper -4.91e-03, Flux lower -4.91e-03, Flux center 5.22e+01
# INFO:root:Time 0.07, Flux left -5.16e-03, Flux right -5.16e-03, Flux upper -5.16e-03, Flux lower -5.16e-03, Flux center 5.30e+01
# INFO:root:Time 0.07, Flux left -5.41e-03, Flux right -5.41e-03, Flux upper -5.41e-03, Flux lower -5.41e-03, Flux center 5.37e+01
# INFO:root:Time 0.08, Flux left -5.65e-03, Flux right -5.65e-03, Flux upper -5.65e-03, Flux lower -5.65e-03, Flux center 5.43e+01
# INFO:root:Time 0.08, Flux left -5.89e-03, Flux right -5.89e-03, Flux upper -5.89e-03, Flux lower -5.89e-03, Flux center 5.50e+01
# INFO:root:Time 0.08, Flux left -6.13e-03, Flux right -6.13e-03, Flux upper -6.13e-03, Flux lower -6.13e-03, Flux center 5.56e+01
# INFO:root:Time 0.08, Flux left -6.36e-03, Flux right -6.36e-03, Flux upper -6.36e-03, Flux lower -6.36e-03, Flux center 5.62e+01
# INFO:root:Time 0.08, Flux left -6.58e-03, Flux right -6.58e-03, Flux upper -6.58e-03, Flux lower -6.58e-03, Flux center 5.68e+01
# INFO:root:Time 0.09, Flux left -6.80e-03, Flux right -6.80e-03, Flux upper -6.80e-03, Flux lower -6.80e-03, Flux center 5.74e+01
# INFO:root:Time 0.09, Flux left -7.02e-03, Flux right -7.02e-03, Flux upper -7.02e-03, Flux lower -7.02e-03, Flux center 5.79e+01
# INFO:root:Time 0.09, Flux left -7.23e-03, Flux right -7.23e-03, Flux upper -7.23e-03, Flux lower -7.23e-03, Flux center 5.84e+01
# INFO:root:Time 0.09, Flux left -7.43e-03, Flux right -7.43e-03, Flux upper -7.43e-03, Flux lower -7.43e-03, Flux center 5.89e+01
# INFO:root:Time 0.09, Flux left -7.63e-03, Flux right -7.63e-03, Flux upper -7.63e-03, Flux lower -7.63e-03, Flux center 5.94e+01
# INFO:root:Time 0.10, Flux left -7.83e-03, Flux right -7.83e-03, Flux upper -7.83e-03, Flux lower -7.83e-03, Flux center 5.98e+01
# INFO:root:Time 0.10, Flux left -8.02e-03, Flux right -8.02e-03, Flux upper -8.02e-03, Flux lower -8.02e-03, Flux center 6.02e+01
# INFO:root:Time 0.10, Flux left -8.20e-03, Flux right -8.20e-03, Flux upper -8.20e-03, Flux lower -8.20e-03, Flux center 6.07e+01
# INFO:root:Time 0.10, Flux left -8.38e-03, Flux right -8.38e-03, Flux upper -8.38e-03, Flux lower -8.38e-03, Flux center 6.10e+01
# INFO:root:Time 0.10, Flux left -8.56e-03, Flux right -8.56e-03, Flux upper -8.56e-03, Flux lower -8.56e-03, Flux center 6.14e+01
# INFO:root:Time 0.11, Flux left -8.72e-03, Flux right -8.72e-03, Flux upper -8.72e-03, Flux lower -8.72e-03, Flux center 6.18e+01
# INFO:root:Time 0.11, Flux left -8.89e-03, Flux right -8.89e-03, Flux upper -8.89e-03, Flux lower -8.89e-03, Flux center 6.21e+01
# INFO:root:Time 0.19, Flux left -1.22e-02, Flux right -1.22e-02, Flux upper -1.22e-02, Flux lower -1.22e-02, Flux center 6.85e+01
# INFO:root:Time 0.19, Flux left -1.23e-02, Flux right -1.23e-02, Flux upper -1.23e-02, Flux lower -1.23e-02, Flux center 6.86e+01
# INFO:root:Time 0.19, Flux left -1.23e-02, Flux right -1.23e-02, Flux upper -1.23e-02, Flux lower -1.23e-02, Flux center 6.86e+01
# INFO:root:Time 0.20, Flux left -1.23e-02, Flux right -1.23e-02, Flux upper -1.23e-02, Flux lower -1.23e-02, Flux center 6.87e+01
# INFO:root:Time 0.20, Flux left -1.23e-02, Flux right -1.23e-02, Flux upper -1.23e-02, Flux lower -1.23e-02, Flux center 6.87e+01
# INFO:root:Time 0.20, Flux left -1.24e-02, Flux right -1.24e-02, Flux upper -1.24e-02, Flux lower -1.24e-02, Flux center 6.88e+01
# INFO:root:Time 0.20, Flux left -1.24e-02, Flux right -1.24e-02, Flux upper -1.24e-02, Flux lower -1.24e-02, Flux center 6.88e+01
# INFO:root:Time 0.20, Flux left -1.24e-02, Flux right -1.24e-02, Flux upper -1.24e-02, Flux lower -1.24e-02, Flux center 6.89e+01
# INFO:root:Time 0.21, Flux left -1.24e-02, Flux right -1.24e-02, Flux upper -1.24e-02, Flux lower -1.24e-02, Flux center 6.89e+01
# INFO:root:Time 0.21, Flux left -1.25e-02, Flux right -1.25e-02, Flux upper -1.25e-02, Flux lower -1.25e-02, Flux center 6.89e+01
# INFO:root:Time 0.21, Flux left -1.25e-02, Flux right -1.25e-02, Flux upper -1.25e-02, Flux lower -1.25e-02, Flux center 6.90e+01
# INFO:root:Time 0.21, Flux left -1.25e-02, Flux right -1.25e-02, Flux upper -1.25e-02, Flux lower -1.25e-02, Flux center 6.90e+01
# INFO:root:Time 0.21, Flux left -1.25e-02, Flux right -1.25e-02, Flux upper -1.25e-02, Flux lower -1.25e-02, Flux center 6.90e+01
# INFO:root:Time 0.22, Flux left -1.25e-02, Flux right -1.25e-02, Flux upper -1.25e-02, Flux lower -1.25e-02, Flux center 6.91e+01
# INFO:root:Time 0.22, Flux left -1.26e-02, Flux right -1.26e-02, Flux upper -1.26e-02, Flux lower -1.26e-02, Flux center 6.91e+01
# INFO:root:Relative mass flow change 1.99829e-05 converged within relatvie tolerance 1e-05
# Widget(value='<iframe src="http://localhost:41155/index.html?ui=P_0x7f4cf412b110_15&reconnect=auto" class="pyv…
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 345
#     342     else:
#     343         fig_as_array = plotter.screenshot("glyphs.png")
# --> 345 pressure_mass_flow_releation = np.vstack([np.array(pressure_list), np.array(final_mass_flow_list)])
#     346 np.savetxt("results/pressure_mass_flow_releation.csv", pressure_mass_flow_releation.T, delimiter=",", header="pressure, flux")
#     348 # %%
#
# File ~/miniconda3/envs/fenicsx-env/lib/python3.13/site-packages/numpy/_core/shape_base.py:291, in vstack(tup, dtype, casting)
#     289 if not isinstance(arrs, tuple):
#     290     arrs = (arrs,)
# --> 291 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 17 and the array at index 1 has size 16
